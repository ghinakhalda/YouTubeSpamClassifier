# %%
# !pip install tokenizers
# !pip install emoji
# Out:
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (0.21.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers) (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (2025.1.31)
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

import re
import string
import spacy
from tokenizers import Tokenizer
import emoji
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from textblob import TextBlob
from textblob import Word
nltk.download("words")
from nltk.corpus import words
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %% [markdown]
# # Import Data

# %%
df_test = pd.read_excel('/content/drive/MyDrive/Year 3 Sem 2/CS4486 Artificial Intelligence/Project (HW 3)/Project 3 (Done)/Topic1-youtube_spam_test.xlsx')
df_train = pd.read_csv('/content/drive/MyDrive/Year 3 Sem 2/CS4486 Artificial Intelligence/Project (HW 3)/Project 3 (Done)/Topic1-youtube_spam_train.csv')

# %%
df_train.tail()
# Out:
#            VIDEO          AUTHOR                 DATE  \
# 793  9bZkp7q19f0     Ben Stalker  2014-11-07T19:27:45
# 794  9bZkp7q19f0  xxxTheMikeTxxx  2014-11-07T19:33:03
# 795  9bZkp7q19f0  Kemal Kurtoglu  2014-11-07T19:33:46
# 796  CevxZvSJLk8    Martwy Karas  2014-11-07T19:33:46
# 797  9bZkp7q19f0   ahmed khalifa  2014-11-07T19:45:26
#
#                                                   TEXT  CLASS
# 793       GANGMAN STY- *D-D-D-D-D-D--DROP THE BASS!!*﻿      0
# 794        Will this song ever reach 7 Billion Views?﻿      0
# 795  Im a RAPPER/SONGWRITER, check my video PLEASE....      1
# 796  Katy Perry's songs are the best of the songs o...      0
# 797  Hello all 29.24% earth population of the world...      0

# %%
df_test.tail()
# Out:
#            VIDEO          AUTHOR                        DATE  \
# 197  KQ6zr6kCPj8      James Wolf  2015-01-23T21:44:55.558000
# 198  KQ6zr6kCPj8  Rafael Diaz Jr  2015-01-25T20:56:06.533000
# 199  KQ6zr6kCPj8  Rafael Diaz Jr  2015-01-25T20:57:46.039000
# 200  KQ6zr6kCPj8   Eric Carbajal  2015-01-26T18:27:00.309000
# 201  KQ6zr6kCPj8    Mizz swagger  2015-01-27T01:53:24.950000
#
#                                                   TEXT  CLASS
# 197                Check out this video on YouTube:ï»¿      1
# 198                Check out this video on YouTube:ï»¿      1
# 199                Check out this video on YouTube:ï»¿      1
# 200                Check out this video on YouTube:ï»¿      1
# 201  ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸš¨ðŸ...      1

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VIDEO   798 non-null    object
#  1   AUTHOR  798 non-null    object
#  2   DATE    798 non-null    object
#  3   TEXT    798 non-null    object
#  4   CLASS   798 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 31.3+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VIDEO   202 non-null    object
#  1   AUTHOR  202 non-null    object
#  2   DATE    202 non-null    object
#  3   TEXT    202 non-null    object
#  4   CLASS   202 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 8.0+ KB

# %%
df_train.groupby('CLASS').describe()
# Out:
#       VIDEO                          AUTHOR                               \
#       count unique          top freq  count unique              top freq
# CLASS
# 0       334      4  CevxZvSJLk8  158    334    322         5000palo    7
# 1       464      4  CevxZvSJLk8  156    464    412  Shadrach Grentz    7
#
#        DATE                                          TEXT         \
#       count unique                         top freq count unique
# CLASS
# 0       334    333  2013-10-05T00:57:25.078000    2   334    322
# 1       464    464         2014-11-06T22:53:08    1   464    435
#
#
#                                      top freq
# CLASS
# 0                            Shakira :-*    4
# 1      Check out this video on YouTube:﻿    7

# %% [markdown]
# # Non-Text Preprocessing

# %%
df_train.isnull().sum()
# Out:
# VIDEO     0
# AUTHOR    0
# DATE      0
# TEXT      0
# CLASS     0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# VIDEO     0
# AUTHOR    0
# DATE      0
# TEXT      0
# CLASS     0
# dtype: int64

# %%
df_train.nunique()
# Out:
# VIDEO       4
# AUTHOR    734
# DATE      796
# TEXT      757
# CLASS       2
# dtype: int64

# %%
df_test.nunique()
# Out:
# VIDEO       3
# AUTHOR    199
# DATE      202
# TEXT      174
# CLASS       2
# dtype: int64

# %% [markdown]
# ## Split date and time

# %%
df_train[['date_info', 'time']] = df_train['DATE'].str.split('T', expand=True)
df_test[['date_info', 'time']] = df_test['DATE'].str.split('T', expand=True)

# %%
df_train['date_info'] = pd.to_datetime(df_train['date_info'])
df_train['time'] = pd.to_timedelta(df_train['time'])

df_test['date_info'] = pd.to_datetime(df_test['date_info'])
df_test['time'] = pd.to_timedelta(df_test['time'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VIDEO      798 non-null    object
#  1   AUTHOR     798 non-null    object
#  2   DATE       798 non-null    object
#  3   TEXT       798 non-null    object
#  4   CLASS      798 non-null    int64
#  5   date_info  798 non-null    datetime64[ns]
#  6   time       798 non-null    timedelta64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4), timedelta64[ns](1)
# memory usage: 43.8+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VIDEO      202 non-null    object
#  1   AUTHOR     202 non-null    object
#  2   DATE       202 non-null    object
#  3   TEXT       202 non-null    object
#  4   CLASS      202 non-null    int64
#  5   date_info  202 non-null    datetime64[ns]
#  6   time       202 non-null    timedelta64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4), timedelta64[ns](1)
# memory usage: 11.2+ KB

# %%
df_train.head()
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
#
#                                                 TEXT  CLASS  date_info  \
# 0                         Shakira is the best dancer      0 2013-07-12
# 1                            Shakira u are so wiredo      0 2013-07-13
# 2                                                wow      0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...      0 2013-07-13
# 4  I love this song because we sing it at Camp al...      0 2013-07-13
#
#                     time
# 0 0 days 22:33:27.916000
# 1 0 days 11:17:52.308000
# 2 0 days 12:09:31.188000
# 3 0 days 13:14:30.021000
# 4 0 days 13:27:39.441000

# %%
date_range = df_train['date_info'].min(), df_train['date_info'].max()

print("Date range:", date_range)
# Out:
# Date range: (Timestamp('2013-07-12 00:00:00'), Timestamp('2014-11-07 00:00:00'))

# %%
max_date = df_train['date_info'].max()
max_year = max_date.year
max_month = max_date.month
max_day = max_date.day

print("Year:", max_year)
print("Month:", max_month)
print("Day:", max_day)
# Out:
# Year: 2014
# Month: 11
# Day: 7

# %%
df_test.head()
# Out:
#          VIDEO                              AUTHOR                 DATE  \
# 0  9bZkp7q19f0                         Adele Lupei  2014-11-07T19:47:06
# 1  9bZkp7q19f0                      Daniel Istrati  2014-11-07T19:47:16
# 2  9bZkp7q19f0                  Stronzo Chicheritr  2014-11-07T20:01:15
# 3  9bZkp7q19f0  none dies virgin life fucks us all  2014-11-07T20:05:35
# 4  9bZkp7q19f0              JakeFrostMiner Palanca  2014-11-07T20:12:11
#
#                                                 TEXT  CLASS  date_info  \
# 0  Is this the video that started the whole "got ...      0 2014-11-07
# 1                Can anyone sub to my channel? :Dï»¿      1 2014-11-07
# 2                      prehistoric song..has beenï»¿      0 2014-11-07
# 3  You think you're smart?        Headbutt your f...      0 2014-11-07
# 4  DISLIKE.. Now one knows REAL music - ex. Enime...      0 2014-11-07
#
#              time
# 0 0 days 19:47:06
# 1 0 days 19:47:16
# 2 0 days 20:01:15
# 3 0 days 20:05:35
# 4 0 days 20:12:11

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Non-text Visualization

# %%
# number of comments from each spam classification group
val = [str(i) for i in df_train['CLASS'].value_counts().index]
print(df_train['CLASS'].value_counts())
print(val)
# Out:
# CLASS
# 1    464
# 0    334
# Name: count, dtype: int64
# ['1', '0']

# %%
df_train['CLASS'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Number of Comments for Each Video ID
df_train['VIDEO'].value_counts()
# Out:
# VIDEO
# CevxZvSJLk8    314
# 9bZkp7q19f0    222
# pRpeEdMmmQ0    200
# KQ6zr6kCPj8     62
# Name: count, dtype: int64

# %%
plt.bar(df_train['VIDEO'].value_counts().index.tolist(), df_train['VIDEO'].value_counts().tolist())
plt.xlabel('Video ID')
plt.ylabel('Number of Comments')
plt.title('Number of Comments for Each Video ID')
plt.show()

# %%
# Number of Comments for Each Video ID, Grouped By Class
video_0 = df_train.loc[df_train['CLASS'] == 0, 'VIDEO'].value_counts()
video_0
# Out:
# VIDEO
# CevxZvSJLk8    158
# 9bZkp7q19f0     92
# pRpeEdMmmQ0     67
# KQ6zr6kCPj8     17
# Name: count, dtype: int64

# %%
video_1 = df_train.loc[df_train['CLASS'] == 1, 'VIDEO'].value_counts()
video_1
# Out:
# VIDEO
# CevxZvSJLk8    156
# pRpeEdMmmQ0    133
# 9bZkp7q19f0    130
# KQ6zr6kCPj8     45
# Name: count, dtype: int64

# %%
count_video = pd.DataFrame({'0': video_0, '1': video_1}).sort_values(by=['1'], ascending=False)
count_video
# Out:
#                0    1
# VIDEO
# CevxZvSJLk8  158  156
# pRpeEdMmmQ0   67  133
# 9bZkp7q19f0   92  130
# KQ6zr6kCPj8   17   45

# %%
x = np.arange(len(count_video))
width = 0.35
fig, ax = plt.subplots(figsize=(10, 6))

im1 = ax.bar(x-width/2, count_video['0'], width, label = 'Class 0')
im2 = ax.bar(x+width/2, count_video['1'], width, label = 'Class 1')

ax.set_xlabel('Video')
ax.set_ylabel('Number of Comments')
ax.set_title('Grouped Bar Chart of Number of Comments per Video')
ax.set_xticks(x)
ax.set_xticklabels(count_video.index)
ax.legend()

def autolabel(ims):
    for im in ims:
        height = im.get_height()
        ax.annotate(f'{height}',
                    xy=(im.get_x() + im.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(im1)
autolabel(im2)

plt.show()

# %%
# Top 10 Authors with Highest Number of Comments
df_train['AUTHOR'].value_counts().sort_values(ascending=False)[:10]
# Out:
# AUTHOR
# 5000palo           7
# Shadrach Grentz    7
# LuckyMusiqLive     5
# Hidden Love        5
# James Cook         4
# OFFICIAL LEXIS     3
# ThirdDegr3e        3
# macgyver16         3
# ricky swaggz       3
# Pyles Baxter       3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(18, 10))
plt.bar(df_train['AUTHOR'].value_counts().sort_values(ascending=False)[:10].index.tolist(), df_train['AUTHOR'].value_counts().sort_values(ascending=False)[:10].tolist())
plt.xlabel('Author')
plt.ylabel('Number of Comments')
plt.title('Top 10 Authors with Highest Number of Comments')
plt.show()

# %%
# list of authors' number of comments
author_all = df_train['AUTHOR'].value_counts()
author_all
# Out:
# AUTHOR
# 5000palo           7
# Shadrach Grentz    7
# LuckyMusiqLive     5
# Hidden Love        5
# James Cook         4
#                   ..
# Evin Alshamas      1
# Nossnevs SWEDEN    1
# maddog1431         1
# MB LOVE            1
# Manuel Ortiz       1
# Name: count, Length: 734, dtype: int64

# %%
# Class 0
author_0 = df_train.loc[df_train['CLASS'] == 0, 'AUTHOR'].value_counts()
author_0
# Out:
# AUTHOR
# 5000palo              7
# tyler sleetway        2
# The Technology Zoo    2
# Alain Bruno           2
# Naga Berapi           2
#                      ..
# xhonavsky             1
# Jack El Matador       1
# Justin Chery          1
# Littleprincess        1
# Kathy L.              1
# Name: count, Length: 322, dtype: int64

# %%
# Top 10 Authors with Highest Number of Comments (Class 1)
author_1 = df_train.loc[df_train['CLASS'] == 1, 'AUTHOR'].value_counts()
author_1
# Out:
# AUTHOR
# Shadrach Grentz    7
# LuckyMusiqLive     5
# Hidden Love        5
# James Cook         4
# Louis Bryant       3
#                   ..
# xXxPWND 420xXx     1
# BaconBro HD        1
# Jdidk Loma         1
# JP Jochem          1
# Aviel Haimov       1
# Name: count, Length: 412, dtype: int64

# %%
count_author = pd.DataFrame({'0': author_0, '1': author_1}).sort_values(by=['1'], ascending=False).fillna(0)
count_author['0'] = count_author['0'].apply(lambda i: int(i))
count_author['1'] = count_author['1'].apply(lambda i: int(i))
count_author
# Out:
#                      0  1
# AUTHOR
# Shadrach Grentz      0  7
# LuckyMusiqLive       0  5
# Hidden Love          0  5
# James Cook           0  4
# Pyles Baxter         0  3
# ...                 .. ..
# ΑΓΛΑΪΑ ΛΕΠΤΟΚΑΡΙΔΟΥ  1  0
# Λυδία Γκ             1  0
# اسيا الخواجة         1  0
# น้ำ ริน              1  0
# 전광용                  1  0
#
# [734 rows x 2 columns]

# %%
count_author.sort_values(by='0', ascending=False)
# Out:
#                                 0  1
# AUTHOR
# 5000palo                        7  0
# Alain Bruno                     2  0
# tyler sleetway                  2  0
# Juan Martinez                   2  0
# Chris Madzier                   2  0
# ...                            .. ..
# TopMusicWorld HD                0  1
# Truc Ng                         0  1
# Tyrek Sings                     0  1
# Unknown Name (buddhist monkie)  0  1
# ThirdDegr3e                     0  3
#
# [734 rows x 2 columns]

# %%
count_author.sort_values(by='1', ascending=False)
# Out:
#                                                    0  1
# AUTHOR
# Shadrach Grentz                                    0  7
# Hidden Love                                        0  5
# LuckyMusiqLive                                     0  5
# James Cook                                         0  4
# roflcopter2110                                     0  3
# ...                                               .. ..
# thevlogmasters Vlog, Challenges en nog veel meer!  1  0
# t tatsuya                                          1  0
# subscrool                                          1  0
# sreekrishna praveen                                1  0
# sebastian hudson                                   1  0
#
# [734 rows x 2 columns]

# %%
count_author[(count_author['0']!=0) & (count_author['1']!=0)]
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %% [markdown]
# Each author has tendency to consistent in one class (either give all spam messages or not)

# %%
# top comments flow based on the date
df_train['date_info'].value_counts().sort_values(ascending=False)[:10]
# Out:
# date_info
# 2014-11-07    52
# 2014-11-06    45
# 2014-11-05    36
# 2014-01-20    21
# 2014-11-04    21
# 2013-10-04    17
# 2014-07-22    16
# 2014-11-02    16
# 2013-10-02    15
# 2014-01-19    13
# Name: count, dtype: int64

# %% [markdown]
# ## Text Visualization

# %% [markdown]
# ### Frequence of Text and Words

# %%
df_train.columns
# Out:
# Index(['VIDEO', 'AUTHOR', 'DATE', 'TEXT', 'CLASS', 'date_info', 'time'], dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VIDEO      798 non-null    object
#  1   AUTHOR     798 non-null    object
#  2   DATE       798 non-null    object
#  3   TEXT       798 non-null    object
#  4   CLASS      798 non-null    int64
#  5   date_info  798 non-null    datetime64[ns]
#  6   time       798 non-null    timedelta64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4), timedelta64[ns](1)
# memory usage: 43.8+ KB

# %%
# The Frequency of Top 10 Comments
df_train['TEXT'].value_counts().sort_values(ascending=False)[:10]
# Out:
# TEXT
# Check out this video on YouTube:﻿                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             7
# Shakira :-*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   4
# Hey Music Fans I really appreciate any of you who will take the time to read this, and check my music out! I&#39;m just a 15 year old boy DREAMING of being a successful MUSICIAN in the music world. I do lots of covers, and piano covers. But I don&#39;t have money to advertise. A simple thumbs up to my comment, a comment on my videos or a SUBSCRIPTION would be a step forward! It will only be a few seconds of your life that you won&#39;t regret!!! Thank u to all the people who just give me a chance! :)     4
# Hi. Check out and share our songs.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            4
# Katy Perry - Roar (Official): http://youtu.be/CevxZvSJLk8﻿                                                                                                                                                                                                                                                                                                                                                                                                                                                                    3
# Hello Guys...I Found a Way to Make Money Online You Can Get Paid To Mess Around On Facebook And Twitter! GET PAID UPTO $25 to $35 AN HOUR...Only at 4NetJobs.com Work from the Comfort of your Home... They are Currently Hiring People from all Over the World, For a Wide Range of Social Media Jobs on Sites such as Facebook,Twitter and YouTube You don&#39;t Need any Prior Skills or Experience and You can Begin Work Immediately! You Can Easily Make $4000 to $5000+ Monthly Income…Only at 4NetJobs.com            3
# wow                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           3
# **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE******CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY NEW MIXTAPE*** ***CHECK OUT MY NEW MIXTAPE****                  3
# Hello everyone :) I know most of you probably pass up these kind of comments, but for those who are still reading this, thanks! I don’t have any money for advertisements, no chance of getting heard, nothing. I live in such a small town... If this comes off as spam, sorry. I’m an instrumental songwriter from Columbus, Mississippi. Please go to my channel and check out my original music. It would be highly appreciated if you thumbs up this comment so my music can be heard! Thank you, Adam Whitney           3
# so beutiful                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2
# Name: count, dtype: int64

# %%
# word cloud (without much text processing) in spam class
punctuations = string.punctuation

sp = spacy.load("en_core_web_sm")
stop_words = sp.Defaults.stop_words

def preprocess1(text):
  doc = sp(text)
  tokenize = [word.lemma_.lower().strip() for word in doc]
  result = [word for word in tokenize if word not in stop_words and word not in punctuations]
  return result

# %%
spam = pd.DataFrame(df_train[df_train['CLASS']==1]['TEXT'])
spam['TEXT'] = spam['TEXT'].apply(lambda i: preprocess1(i))
spam
# Out:
#                                                   TEXT
# 8    [check, new, mixtape, check, new, mixtape, che...
# 9    [check, new, mixtape, check, new, mixtape, che...
# 10   [check, new, mixtape, check, new, mixtape, che...
# 11   [hey, music, fans, appreciate, time, read, che...
# 12   [omg, facebook, old, check, -----------------&...
# ..                                                 ...
# 784  [friend, read, book, repass, http://www.4share...
# 785                                 [subscribe, :), ﻿]
# 788  [nowplaye, weekendmix, track, 04, katy, perry,...
# 790  [hello, kind, new, youtube, soon, soon, launch...
# 795  [m, rapper, songwriter, check, video, .., subs...
#
# [464 rows x 1 columns]

# %%
spam_wc = WordCloud(width=500, height=500).generate(' '.join([i for j in spam['TEXT'] for i in j]))
plt.figure(figsize=(10,8), facecolor='k')
plt.imshow(spam_wc)
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
spam_freq = spam_wc.words_
sorted(spam_freq.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('subscribe', 1.0),
#  ('amp', 0.696969696969697),
#  ('check new', 0.5959595959595959),
#  ('channel', 0.5656565656565656),
#  ('video', 0.5151515151515151),
#  ('thank', 0.494949494949495),
#  ('song', 0.48484848484848486),
#  ('new mixtape', 0.48484848484848486),
#  ('https', 0.47474747474747475),
#  ('mixtape check', 0.47474747474747475)]

# %%
# word cloud (without much text processing) in non-spam class
non_spam = pd.DataFrame(df_train[df_train['CLASS']==0]['TEXT'])
non_spam['TEXT'] = non_spam['TEXT'].apply(lambda i: preprocess1(i))
non_spam
# Out:
#                                                   TEXT
# 0                              [shakira, good, dancer]
# 1                                 [shakira, u, wiredo]
# 2                                                [wow]
# 3    [love, song, reason, 1.it, africa, 2.i, bear, ...
# 4                       [love, song, sing, camp, time]
# ..                                                 ...
# 792  [2, billion, view, piece, shit, ..., r, e, y, ...
# 793  [gangman, sty-, d, d, d, d, d, d, --, drop, ba...
# 794                 [song, reach, 7, billion, views?﻿]
# 796  [katy, perry, song, good, song, woman, artists.﻿]
# 797  [hello, 29.24, earth, population, world, hope,...
#
# [334 rows x 1 columns]

# %%
nonspam_wc = WordCloud(width=500, height=500).generate(' '.join([i for j in non_spam['TEXT'] for i in j]))
plt.figure(figsize=(10,8), facecolor='k')
plt.imshow(nonspam_wc)
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
nonspam_freq = nonspam_wc.words_
sorted(nonspam_freq.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('song', 1.0),
#  ('video', 1.0),
#  ('katy perry', 0.7755102040816326),
#  ('love', 0.673469387755102),
#  ('view', 0.5102040816326531),
#  ('good', 0.42857142857142855),
#  ('people', 0.3469387755102041),
#  ('shakira', 0.32653061224489793),
#  ('music', 0.32653061224489793),
#  ('come', 0.30612244897959184)]

# %%
# stop word
df_train['stopWord'] = df_train['TEXT'].apply(lambda i: len([j for j in str(i).lower().split() if j in stop_words]))
df_train.head()
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
#
#                                                 TEXT  CLASS  date_info  \
# 0                         Shakira is the best dancer      0 2013-07-12
# 1                            Shakira u are so wiredo      0 2013-07-13
# 2                                                wow      0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...      0 2013-07-13
# 4  I love this song because we sing it at Camp al...      0 2013-07-13
#
#                     time  stopWord
# 0 0 days 22:33:27.916000         2
# 1 0 days 11:17:52.308000         2
# 2 0 days 12:09:31.188000         0
# 3 0 days 13:14:30.021000         8
# 4 0 days 13:27:39.441000         8

# %%
df_train['stopWord'].hist()

plt.xlabel('Stop Words')
plt.ylabel('Count')
plt.title('Number of Stop Words')
plt.show()

# %%
sns.kdeplot(df_train[df_train['CLASS']==0]['stopWord'], color='b')
sns.kdeplot(df_train[df_train['CLASS']==1]['stopWord'], color='r')
plt.legend(['Non-spam', 'Spam'])

# %% [markdown]
# # Text Preprocessing & Feature Selection

# %% [markdown]
# ## Text Preprocessing

# %%
punctuations = string.punctuation
print(punctuations)

sp = spacy.load("en_core_web_sm")
stop_words = sp.Defaults.stop_words
add_sw = {"omg", 'lol'}
stop_words.update(add_sw)
print(stop_words)

english_words = set(words.words())
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# {'they', 'himself', 'into', 'this', 'should', 'you', 'thence', 'everyone', 'anyhow', 'after', 'whereby', 'has', 'your', 'wherever', 'besides', 'herself', 'were', 'seem', 'why', 'name', 'sometimes', 'up', 'nothing', "'ve", '‘ll', 'toward', 'rather', 'on', 'eight', 'make', 'three', 'therefore', 'never', 'beside', 'behind', 'whenever', 'anyone', 'used', 'that', 'am', 'almost', 'anywhere', 'regarding', 'herein', 'serious', 'was', '‘s', 'only', 'enough', 'two', 'does', 'every', 'there', 'here', 'lol', 'could', 'be', 'most', 'many', 'say', 'fifty', 'among', 'namely', 'six', 'always', 'omg', 'him', 'for', 'whereas', 'therein', 'per', 'hereby', 'is', 'cannot', 'if', 'five', 'from', 're', 'over', 'former', 'anything', 'becomes', 'seeming', 'he', 'what', 'do', 'became', 'get', 'nobody', "'re", 'it', 'using', 'his', 'latterly', 'below', 'even', 'somewhere', 'me', 'around', 'become', 'though', 'once', "'m", 'least', 'along', 'neither', 'are', 'less', 'call', 'ours', 'within', 'also', 'much', '‘re', 'might', 'moreover', 'very', '‘d', 'together', 'fifteen', 'than', 'third', 'have', 'give', 'both', 'wherein', 'seemed', 'everything', 'until', 'between', 'either', 'well', 'none', 'its', 'noone', 'thus', 'yours', 'one', 'their', 'thereafter', 'last', 'through', 'yet', '’re', 'really', 'ca', 'an', 'whatever', 'being', 'n‘t', 'them', 'top', 'itself', 'although', 'by', 'and', 'whence', 'across', 'these', 'several', 'thru', 'becoming', 'further', 'often', 'due', 'so', 'full', 'any', 'go', 'not', 'done', 'will', 'amount', 'something', 'beyond', 'in', 'others', 'see', '’d', 'to', 'n’t', 'with', 'whose', 'too', 'before', 'whom', 'eleven', 'off', 'seems', 'empty', 'because', 'few', 'of', 'made', 'some', 'bottom', 'nevertheless', 'each', 'no', 'except', '’ve', 'thereupon', 'hereupon', 'doing', 'thereby', 'ten', 'at', 'while', 'themselves', 'indeed', 'our', 'amongst', 'quite', 'back', 'she', 'however', 'hers', 'may', 'we', 'hereafter', 'put', 'whether', 'my', 'throughout', 'as', 'take', "'s", 'side', 'else', 'ourselves', 'four', 'i', 'someone', 'would', 'did', 'just', 'then', 'a', "n't", 'beforehand', 'mine', 'who', 'must', 'same', '‘ve', '‘m', 'nowhere', 'upon', 'yourselves', 'keep', 'unless', 'everywhere', 'onto', 'nor', 'via', 'against', 'own', 'first', 'again', 'out', 'above', 'but', 'elsewhere', 'yourself', 'whither', 'twenty', 'or', 'mostly', 'whoever', 'been', 'formerly', '’ll', 'now', 'which', 'during', 'the', '’m', 'anyway', 'can', 'had', 'otherwise', 'another', 'show', 'meanwhile', 'since', 'sometime', "'d", 'whereupon', 'hundred', 'still', 'alone', 'move', 'perhaps', 'down', 'how', 'please', 'forty', 'such', 'towards', 'various', 'under', '’s', 'hence', 'part', 'twelve', 'all', 'latter', 'where', 'myself', 'already', 'sixty', 'other', 'about', 'us', 'somehow', 'without', 'front', 'more', 'her', 'next', 'afterwards', 'whereafter', "'ll", 'those', 'when', 'whole', 'nine', 'ever'}

# %%
def preprocess_all(text):
  text = emoji.demojize(text)
  # remove special characters
  text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
  text = re.sub(r'\s+', ' ', text)

  # remove repeated characters
  text = re.sub(r'(.)\1+', r'\1', text)

  doc = sp(text)
  tokenize = [word.lemma_.lower().strip() for word in doc]
  result = [word for word in tokenize if word not in stop_words and word not in punctuations]
  result = [word for word in result if len(word)>1]
  return result

df_train['pre_text'] = df_train['TEXT'].apply(lambda i: preprocess_all(i))
df_test['pre_text'] = df_test['TEXT'].apply(lambda i: preprocess_all(i))
df_train.head()
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
#
#                                                 TEXT  CLASS  date_info  \
# 0                         Shakira is the best dancer      0 2013-07-12
# 1                            Shakira u are so wiredo      0 2013-07-13
# 2                                                wow      0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...      0 2013-07-13
# 4  I love this song because we sing it at Camp al...      0 2013-07-13
#
#                     time                                           pre_text
# 0 0 days 22:33:27.916000                            [shakira, good, dancer]
# 1 0 days 11:17:52.308000                                  [shakira, wiredo]
# 2 0 days 12:09:31.188000                                              [wow]
# 3 0 days 13:14:30.021000  [love, song, reason, africa, bear, beautiful, ...
# 4 0 days 13:27:39.441000                 [love, song, sing, camp, al, time]

# %%
df_train.head()
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
#
#                                                 TEXT  CLASS  date_info  \
# 0                         Shakira is the best dancer      0 2013-07-12
# 1                            Shakira u are so wiredo      0 2013-07-13
# 2                                                wow      0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...      0 2013-07-13
# 4  I love this song because we sing it at Camp al...      0 2013-07-13
#
#                     time                                           pre_text
# 0 0 days 22:33:27.916000                            [shakira, good, dancer]
# 1 0 days 11:17:52.308000                                  [shakira, wiredo]
# 2 0 days 12:09:31.188000                                              [wow]
# 3 0 days 13:14:30.021000  [love, song, reason, africa, bear, beautiful, ...
# 4 0 days 13:27:39.441000                 [love, song, sing, camp, al, time]

# %% [markdown]
# ## Word and Characters Visualization

# %%
# word length
df_train['word_length'] = df_train['pre_text'].apply(lambda i: len(i))
df_train.head()
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
#
#                                                 TEXT  CLASS  date_info  \
# 0                         Shakira is the best dancer      0 2013-07-12
# 1                            Shakira u are so wiredo      0 2013-07-13
# 2                                                wow      0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...      0 2013-07-13
# 4  I love this song because we sing it at Camp al...      0 2013-07-13
#
#                     time                                           pre_text  \
# 0 0 days 22:33:27.916000                            [shakira, good, dancer]
# 1 0 days 11:17:52.308000                                  [shakira, wiredo]
# 2 0 days 12:09:31.188000                                              [wow]
# 3 0 days 13:14:30.021000  [love, song, reason, africa, bear, beautiful, ...
# 4 0 days 13:27:39.441000                 [love, song, sing, camp, al, time]
#
#    word_length
# 0            3
# 1            2
# 2            1
# 3            8
# 4            6

# %%
df_train['word_length'].hist()
plt.xlabel('Word Length')
plt.ylabel('Count')
plt.title('Word Length for All Comments')
plt.show()

# %%
sns.kdeplot(df_train[df_train['CLASS']==0]['word_length'], color='b')
sns.kdeplot(df_train[df_train['CLASS']==1]['word_length'], color='r')
plt.legend(['Non-spam', 'Spam'])
plt.show()

# %%
# character length
# number of characters
df_train['char_length'] = df_train['pre_text'].apply(lambda i: sum(len(j) for j in i))
df_train.head()
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
#
#                                                 TEXT  CLASS  date_info  \
# 0                         Shakira is the best dancer      0 2013-07-12
# 1                            Shakira u are so wiredo      0 2013-07-13
# 2                                                wow      0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...      0 2013-07-13
# 4  I love this song because we sing it at Camp al...      0 2013-07-13
#
#                     time                                           pre_text  \
# 0 0 days 22:33:27.916000                            [shakira, good, dancer]
# 1 0 days 11:17:52.308000                                  [shakira, wiredo]
# 2 0 days 12:09:31.188000                                              [wow]
# 3 0 days 13:14:30.021000  [love, song, reason, africa, bear, beautiful, ...
# 4 0 days 13:27:39.441000                 [love, song, sing, camp, al, time]
#
#    word_length  char_length
# 0            3           17
# 1            2           13
# 2            1            3
# 3            8           44
# 4            6           22

# %%
sns.displot(data=df_train, x='char_length', hue='VIDEO', bins=30, multiple='layer', kde=False)

plt.xlabel('Number of Characters of Comments')
plt.ylabel('Count')
plt.title('Histogram of Characters Frequency by Video')
plt.legend()
plt.show()
# Out:
# <ipython-input-280-27e36fcb957e>:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.boxplot(data=df_train, x='VIDEO', y='char_length')

plt.xlabel('Video')
plt.ylabel('Count')
plt.title('Boxplot of Characters Frequency by Video')
plt.legend()
plt.show()
# Out:
# <ipython-input-281-0676285da262>:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_train['CLASS'] = df_train['CLASS'].astype('category')
sns.displot(data=df_train, x='char_length', hue='CLASS', bins=30, multiple='layer', kde=False)

plt.xlabel('Number of Characters of Comments')
plt.ylabel('Count')
plt.title('Histogram of Characters Frequency by Class')
plt.legend()
plt.show()
# Out:
# <ipython-input-282-df04cc894f5e>:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.scatterplot(data=df_train, x='char_length', y='word_length')
# Out:
# <Axes: xlabel='char_length', ylabel='word_length'>

# %%
stats.probplot(df_train['word_length'], plot=plt)
plt.show()

# %%
stats.probplot(df_train['char_length'], plot=plt)
plt.show()

# %%
df_train.columns
# Out:
# Index(['VIDEO', 'AUTHOR', 'DATE', 'TEXT', 'CLASS', 'date_info', 'time',
#        'pre_text', 'word_length', 'char_length'],
#       dtype='object')

# %%
# unique words
df_train['len_unique_word'] = df_train['pre_text'].apply(lambda i: len(set(i)))
df_train.head(10)
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
# 5  pRpeEdMmmQ0         Dinova Sharon  2013-07-13T14:44:00.700000
# 6  pRpeEdMmmQ0       TheHotChocolate  2013-07-13T18:26:37.017000
# 7  pRpeEdMmmQ0      Ysobel Schofield  2013-07-13T20:17:25.181000
# 8  pRpeEdMmmQ0           ThirdDegr3e  2013-07-13T20:47:40.793000
# 9  pRpeEdMmmQ0           ThirdDegr3e  2013-07-13T20:48:06.033000
#
#                                                 TEXT CLASS  date_info  \
# 0                         Shakira is the best dancer     0 2013-07-12
# 1                            Shakira u are so wiredo     0 2013-07-13
# 2                                                wow     0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...     0 2013-07-13
# 4  I love this song because we sing it at Camp al...     0 2013-07-13
# 5                                  well done shakira     0 2013-07-13
# 6                           she is sooooo beautiful!     0 2013-07-13
# 7                                Waka waka she rules     0 2013-07-13
# 8  **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY ...     1 2013-07-13
# 9  **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY ...     1 2013-07-13
#
#                     time                                           pre_text  \
# 0 0 days 22:33:27.916000                            [shakira, good, dancer]
# 1 0 days 11:17:52.308000                                  [shakira, wiredo]
# 2 0 days 12:09:31.188000                                              [wow]
# 3 0 days 13:14:30.021000  [love, song, reason, africa, bear, beautiful, ...
# 4 0 days 13:27:39.441000                 [love, song, sing, camp, al, time]
# 5 0 days 14:44:00.700000                                     [wel, shakira]
# 6 0 days 18:26:37.017000                                        [beautiful]
# 7 0 days 20:17:25.181000                                 [waka, waka, rule]
# 8 0 days 20:47:40.793000  [check, new, mixtape, check, new, mixtape, che...
# 9 0 days 20:48:06.033000  [check, new, mixtape, check, new, mixtape, che...
#
#    word_length  char_length  len_unique_word
# 0            3           17                3
# 1            2           13                2
# 2            1            3                1
# 3            8           44                7
# 4            6           22                6
# 5            2           10                2
# 6            1            9                1
# 7            3           12                2
# 8           48          240                3
# 9           48          240                3

# %%
df_train['len_unique_word'].hist()
plt.xlabel('Number of Unique Words')
plt.ylabel('Count')
plt.title('Histogram of Unique Words')
plt.show()

# %%
sns.kdeplot(df_train[df_train['CLASS']==0]['len_unique_word'], color='b')
sns.kdeplot(df_train[df_train['CLASS']==1]['len_unique_word'], color='r')
plt.legend(['Non-spam', 'Spam'])
plt.show()

# %%
sns.scatterplot(data=df_train, x='char_length', y='len_unique_word')
# Out:
# <Axes: xlabel='char_length', ylabel='len_unique_word'>

# %%
sns.scatterplot(data=df_train, x='word_length', y='len_unique_word')
# Out:
# <Axes: xlabel='word_length', ylabel='len_unique_word'>

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ###Train data

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VIDEO      798 non-null    object
#  1   AUTHOR     798 non-null    object
#  2   DATE       798 non-null    object
#  3   TEXT       798 non-null    object
#  4   CLASS      798 non-null    int64
#  5   date_info  798 non-null    datetime64[ns]
#  6   time       798 non-null    timedelta64[ns]
#  7   pre_text   798 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5), timedelta64[ns](1)
# memory usage: 50.0+ KB

# %%
df_train['all_message'] = df_train['pre_text'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
df_train.head()
# Out:
#          VIDEO                AUTHOR                        DATE  \
# 0  pRpeEdMmmQ0           Latin Bosch  2013-07-12T22:33:27.916000
# 1  pRpeEdMmmQ0        Aishlin Maciel  2013-07-13T11:17:52.308000
# 2  pRpeEdMmmQ0         jeffrey jules  2013-07-13T12:09:31.188000
# 3  pRpeEdMmmQ0  Sabina Pearson-Smith  2013-07-13T13:14:30.021000
# 4  pRpeEdMmmQ0          Katie Mettam  2013-07-13T13:27:39.441000
#
#                                                 TEXT  CLASS  date_info  \
# 0                         Shakira is the best dancer      0 2013-07-12
# 1                            Shakira u are so wiredo      0 2013-07-13
# 2                                                wow      0 2013-07-13
# 3  I love this song for two reasons: 1.it is abou...      0 2013-07-13
# 4  I love this song because we sing it at Camp al...      0 2013-07-13
#
#                     time                                           pre_text  \
# 0 0 days 22:33:27.916000                            [shakira, good, dancer]
# 1 0 days 11:17:52.308000                                  [shakira, wiredo]
# 2 0 days 12:09:31.188000                                              [wow]
# 3 0 days 13:14:30.021000  [love, song, reason, africa, bear, beautiful, ...
# 4 0 days 13:27:39.441000                 [love, song, sing, camp, al, time]
#
#                                          all_message
# 0                                shakira good dancer
# 1                                     shakira wiredo
# 2                                                wow
# 3  love song reason africa bear beautiful south a...
# 4                        love song sing camp al time

# %%
from sklearn.preprocessing import OneHotEncoder
author_encoder = OneHotEncoder(handle_unknown='ignore')
video_encoder = OneHotEncoder(handle_unknown='ignore')
X_author = author_encoder.fit_transform(df_train[['AUTHOR']])
X_video = video_encoder.fit_transform(df_train[['VIDEO']])

# %%
# using tf-idf
tfIdf_vec = TfidfVectorizer(ngram_range=(1, 2))
x = tfIdf_vec.fit_transform(df_train['all_message'])

# %%
from scipy.sparse import hstack
X_combined = hstack([x, X_author, X_video])

# %% [markdown]
# ### Test data

# %%
df_test['all_message'] = df_test['pre_text'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
df_test.head()
# Out:
#          VIDEO                              AUTHOR                 DATE  \
# 0  9bZkp7q19f0                         Adele Lupei  2014-11-07T19:47:06
# 1  9bZkp7q19f0                      Daniel Istrati  2014-11-07T19:47:16
# 2  9bZkp7q19f0                  Stronzo Chicheritr  2014-11-07T20:01:15
# 3  9bZkp7q19f0  none dies virgin life fucks us all  2014-11-07T20:05:35
# 4  9bZkp7q19f0              JakeFrostMiner Palanca  2014-11-07T20:12:11
#
#                                                 TEXT  CLASS  date_info  \
# 0  Is this the video that started the whole "got ...      0 2014-11-07
# 1                Can anyone sub to my channel? :Dï»¿      1 2014-11-07
# 2                      prehistoric song..has beenï»¿      0 2014-11-07
# 3  You think you're smart?        Headbutt your f...      0 2014-11-07
# 4  DISLIKE.. Now one knows REAL music - ex. Enime...      0 2014-11-07
#
#              time                                           pre_text  \
# 0 0 days 19:47:06  [video, start, dick, stick, elevator, excuse, ...
# 1 0 days 19:47:16                                      [sub, chanel]
# 2 0 days 20:01:15                           [prehistoric, song, ben]
# 3 0 days 20:05:35                      [think, smart, headbut, face]
# 4 0 days 20:12:11           [dislike, know, real, music, ex, eniman]
#
#                                     all_message
# 0  video start dick stick elevator excuse thing
# 1                                    sub chanel
# 2                          prehistoric song ben
# 3                      think smart headbut face
# 4             dislike know real music ex eniman

# %%
X_author_test = author_encoder.transform(df_test[['AUTHOR']])
X_video_test = video_encoder.transform(df_test[['VIDEO']])

# using tf-idf
X_test = tfIdf_vec.transform(df_test['all_message'])
X_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1422 stored elements and shape (202, 7744)>

# %%
x_test = hstack([X_test, X_author_test, X_video_test])
x_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1626 stored elements and shape (202, 8482)>

# %% [markdown]
# # Classification

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay, roc_curve
from sklearn import metrics
import math
from sklearn.linear_model import LogisticRegressionCV
import time
from sklearn.model_selection import RandomizedSearchCV

# %%
x_train, x_val, y_train, y_val = train_test_split(X_combined, df_train['CLASS'], test_size=0.3, random_state=42)
print(f"Train features shape: {x_train.shape}")
print(f"Validation features shape: {x_val.shape}")
print(f"Train label shape: {y_train.shape}")
print(f"Validation label shape: {y_val.shape}")
# Out:
# Train features shape: (558, 8482)
# Validation features shape: (240, 8482)
# Train label shape: (558,)
# Validation label shape: (240,)

# %%
y_test = df_test['CLASS']
# y_test

# %%
def metrics_eval(y_val, y_pred):
  acc = accuracy_score(y_val, y_pred)
  prec = precision_score(y_val, y_pred)
  rec = recall_score(y_val, y_pred)
  f1Score = f1_score(y_val, y_pred)
  auc_roc = roc_auc_score(y_val, y_pred)
  confusion = confusion_matrix(y_val, y_pred)
  tn, fp, fn, tp = confusion.ravel()
  specificity = tn / (tn+fp)
  NPV = tn / (tn+fn)

  print(f"Accuracy: {acc}")
  print(f"Precision: {prec}")
  print(f"Recall: {rec}")
  print(f"f1-score: {f1Score}")
  print(f"NPV: {NPV}")
  print(f"Specificity: {specificity}")
  return acc, prec, rec, f1Score, NPV, specificity

# %%
def conf_mat(data):
  plt.figure(figsize=(6, 4))
  sns.heatmap(data, annot=True, cbar=False, fmt='d')
  plt.xlabel('Predicted Label')
  plt.ylabel('True Label')
  plt.title('Confusion Matrix')
  plt.show()

# %%
def class_rep(y_val, y_pred):
  cr = metrics.classification_report(y_val, y_pred, output_dict=True)
  nb_report=pd.DataFrame(cr).transpose()
  print(nb_report)

# %%
model_trainTime = {}
model_ht_trainTime = {}

# %%
model_Performance={}

# %% [markdown]
# ## Naive Bayes

# %%
nb = MultinomialNB()
start_time = time.perf_counter()
nb_model = nb.fit(x_train, y_train)
training_time = time.perf_counter() - start_time
model_trainTime['Naive_Bayes'] = training_time
print(f"Training time: {model_trainTime['Naive_Bayes']:.4f} seconds")

y_pred = nb.predict(x_val)
# Out:
# Training time: 0.0159 seconds

# %%
class_rep(y_val, y_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.894118  0.752475  0.817204  101.000000
# 1              0.838710  0.935252  0.884354  139.000000
# accuracy       0.858333  0.858333  0.858333    0.858333
# macro avg      0.866414  0.843864  0.850779  240.000000
# weighted avg   0.862027  0.858333  0.856095  240.000000

# %%
nb_cm = metrics.confusion_matrix(y_val, y_pred)
conf_mat(nb_cm)

# %%
metrics_eval(y_val, y_pred)
# Out:
# Accuracy: 0.8583333333333333
# Precision: 0.8387096774193549
# Recall: 0.935251798561151
# f1-score: 0.8843537414965986
# NPV: 0.8941176470588236
# Specificity: 0.7524752475247525
# (0.8583333333333333,
#  0.8387096774193549,
#  0.935251798561151,
#  0.8843537414965986,
#  np.float64(0.8941176470588236),
#  np.float64(0.7524752475247525))

# %%
# testing
y_test_pred = nb.predict(x_test)

class_rep(y_test, y_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              1.000000  0.467391  0.637037   92.000000
# 1              0.691824  1.000000  0.817844  110.000000
# accuracy       0.757426  0.757426  0.757426    0.757426
# macro avg      0.845912  0.733696  0.727440  202.000000
# weighted avg   0.832181  0.757426  0.735496  202.000000

# %%
nb_cm_test = metrics.confusion_matrix(y_test, y_test_pred)
conf_mat(nb_cm_test)

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, y_test_pred)
# Out:
# Accuracy: 0.7574257425742574
# Precision: 0.6918238993710691
# Recall: 1.0
# f1-score: 0.8178438661710037
# NPV: 1.0
# Specificity: 0.4673913043478261

# %%
model_Performance['Naive Bayes']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['Naive Bayes']
# Out:
# [0.7574257425742574,
#  0.6918238993710691,
#  1.0,
#  0.8178438661710037,
#  np.float64(1.0),
#  np.float64(0.4673913043478261)]

# %% [markdown]
# ## Naive Bayes (Adjust Parameter)

# %%
param_dist = {
    'alpha': np.logspace(-3, 2, 100),
    'fit_prior': [True, False]
}

nb = MultinomialNB()

start_time = time.perf_counter()
nb_rs = RandomizedSearchCV(nb, param_dist, n_iter=20, cv=5, scoring='f1', random_state=42)
nb_model = nb_rs.fit(x_train, y_train)
training_time = time.perf_counter() - start_time
model_ht_trainTime['Naive_Bayes'] = training_time
print(f"Training time: {model_trainTime['Naive_Bayes']:.4f} seconds")

y_pred = nb_model.predict(x_val)
# Out:
# Training time: 0.0159 seconds

# %%
class_rep(y_val, y_pred)
# Out:
#               precision    recall  f1-score  support
# 0              0.814159  0.910891  0.859813  101.000
# 1              0.929134  0.848921  0.887218  139.000
# accuracy       0.875000  0.875000  0.875000    0.875
# macro avg      0.871647  0.879906  0.873516  240.000
# weighted avg   0.880749  0.875000  0.875685  240.000

# %%
nb_cm = metrics.confusion_matrix(y_val, y_pred)
conf_mat(nb_cm)

# %%
metrics_eval(y_val, y_pred)
# Out:
# Accuracy: 0.875
# Precision: 0.9291338582677166
# Recall: 0.8489208633093526
# f1-score: 0.8872180451127819
# NPV: 0.8141592920353983
# Specificity: 0.9108910891089109
# (0.875,
#  0.9291338582677166,
#  0.8489208633093526,
#  0.8872180451127819,
#  np.float64(0.8141592920353983),
#  np.float64(0.9108910891089109))

# %%
# testing
y_test_pred = nb_model.predict(x_test)

class_rep(y_test, y_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.954545  0.684783  0.797468   92.000000
# 1              0.786765  0.972727  0.869919  110.000000
# accuracy       0.841584  0.841584  0.841584    0.841584
# macro avg      0.870655  0.828755  0.833694  202.000000
# weighted avg   0.863180  0.841584  0.836922  202.000000

# %%
nb_cm_test = metrics.confusion_matrix(y_test, y_test_pred)
conf_mat(nb_cm_test)

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, y_test_pred)
# Out:
# Accuracy: 0.8415841584158416
# Precision: 0.7867647058823529
# Recall: 0.9727272727272728
# f1-score: 0.8699186991869918
# NPV: 0.9545454545454546
# Specificity: 0.6847826086956522

# %%
model_Performance['Naive Bayes (Hyperparameter Tuning)']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['Naive Bayes (Hyperparameter Tuning)']
# Out:
# [0.8415841584158416,
#  0.7867647058823529,
#  0.9727272727272728,
#  0.8699186991869918,
#  np.float64(0.9545454545454546),
#  np.float64(0.6847826086956522)]

# %% [markdown]
# ## Logistic Regression

# %%
lr_model = LogisticRegression(random_state=42)
start_time = time.perf_counter()
lr_model.fit(x_train, y_train)
training_time = time.perf_counter() - start_time
model_trainTime['LR'] = training_time
y_pred_lr = lr_model.predict(x_val)

# %%
metrics_eval(y_val, y_pred_lr)
# Out:
# Accuracy: 0.8625
# Precision: 0.8486842105263158
# Recall: 0.9280575539568345
# f1-score: 0.8865979381443299
# NPV: 0.8863636363636364
# Specificity: 0.7722772277227723
# (0.8625,
#  0.8486842105263158,
#  0.9280575539568345,
#  0.8865979381443299,
#  np.float64(0.8863636363636364),
#  np.float64(0.7722772277227723))

# %%
class_rep(y_val, y_pred_lr)
# Out:
#               precision    recall  f1-score   support
# 0              0.886364  0.772277  0.825397  101.0000
# 1              0.848684  0.928058  0.886598  139.0000
# accuracy       0.862500  0.862500  0.862500    0.8625
# macro avg      0.867524  0.850167  0.855997  240.0000
# weighted avg   0.864541  0.862500  0.860842  240.0000

# %%
lr_cm = metrics.confusion_matrix(y_val, y_pred_lr)
conf_mat(lr_cm)

# %%
# testing
ylr_test_pred = lr_model.predict(x_test)
class_rep(y_test, ylr_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.967742  0.652174  0.779221   92.000000
# 1              0.771429  0.981818  0.864000  110.000000
# accuracy       0.831683  0.831683  0.831683    0.831683
# macro avg      0.869585  0.816996  0.821610  202.000000
# weighted avg   0.860839  0.831683  0.825388  202.000000

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, ylr_test_pred)
# Out:
# Accuracy: 0.8316831683168316
# Precision: 0.7714285714285715
# Recall: 0.9818181818181818
# f1-score: 0.864
# NPV: 0.967741935483871
# Specificity: 0.6521739130434783

# %%
lr_cm_test = metrics.confusion_matrix(y_test, ylr_test_pred)
conf_mat(lr_cm_test)

# %%
model_Performance['Logistic Regression']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['Logistic Regression']
# Out:
# [0.8316831683168316,
#  0.7714285714285715,
#  0.9818181818181818,
#  0.864,
#  np.float64(0.967741935483871),
#  np.float64(0.6521739130434783)]

# %% [markdown]
# ## Logistic Regression (Adjust Parameter)

# %%
lr_model1 = LogisticRegressionCV(Cs=list(np.power(10.0, np.arange(5, -6, -1))), cv=5, scoring='roc_auc', penalty='l2',
                           solver='newton-cg', max_iter=30000, random_state=42)
start_time = time.perf_counter()
lr_model1.fit(x_train, y_train)

print(f'AUC-ROC of Spam: {lr_model1.scores_[1].mean(axis=0)}')
print(f'The max AUC-ROC score: {lr_model1.scores_[1].mean(axis=0).max()}')

i = np.where(lr_model1.scores_[1].mean(axis=0)==lr_model1.scores_[1].mean(axis=0).max())
Cs = list(np.power(10.0, np.arange(5, -6, -1)))
Cs_select = Cs[int(i[0][0])]
print(f'Lambda = { 1/Cs[int(i[0][0])]}')

lr_model = LogisticRegression(random_state=42, C=Cs_select, penalty='l2', max_iter=30000).fit(x_train, y_train)
model_ht_trainTime['LR'] = time.perf_counter() - start_time
print(f"Training time: {model_ht_trainTime['LR']:.4f} seconds")

y_pred_lr = lr_model.predict(x_val)
# Out:
# AUC-ROC of Spam: [0.96897602 0.96897602 0.96897602 0.96662777 0.96238383 0.94053369
#  0.79748666 0.75176546 0.7475386  0.74720843 0.74720843]
# The max AUC-ROC score: 0.9689760193552978
# Lambda = 1e-05
# Training time: 2.6478 seconds

# %%
metrics_eval(y_val, y_pred_lr)
# Out:
# Accuracy: 0.9166666666666666
# Precision: 0.9343065693430657
# Recall: 0.920863309352518
# f1-score: 0.927536231884058
# NPV: 0.8932038834951457
# Specificity: 0.9108910891089109
# (0.9166666666666666,
#  0.9343065693430657,
#  0.920863309352518,
#  0.927536231884058,
#  np.float64(0.8932038834951457),
#  np.float64(0.9108910891089109))

# %%
class_rep(y_val, y_pred_lr)
# Out:
#               precision    recall  f1-score     support
# 0              0.893204  0.910891  0.901961  101.000000
# 1              0.934307  0.920863  0.927536  139.000000
# accuracy       0.916667  0.916667  0.916667    0.916667
# macro avg      0.913755  0.915877  0.914749  240.000000
# weighted avg   0.917009  0.916667  0.916773  240.000000

# %%
lr_cm = metrics.confusion_matrix(y_val, y_pred_lr)
conf_mat(lr_cm)

# %%
# testing
ylr_test_pred = lr_model.predict(x_test)
class_rep(y_test, ylr_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.952941  0.880435  0.915254   92.000000
# 1              0.905983  0.963636  0.933921  110.000000
# accuracy       0.925743  0.925743  0.925743    0.925743
# macro avg      0.929462  0.922036  0.924587  202.000000
# weighted avg   0.927370  0.925743  0.925419  202.000000

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, ylr_test_pred)
# Out:
# Accuracy: 0.9257425742574258
# Precision: 0.905982905982906
# Recall: 0.9636363636363636
# f1-score: 0.933920704845815
# NPV: 0.9529411764705882
# Specificity: 0.8804347826086957

# %%
lr_cm_test = metrics.confusion_matrix(y_test, ylr_test_pred)
conf_mat(lr_cm_test)

# %%
model_Performance['Logistic Regression (Hyperparameter Tuning)']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['Logistic Regression (Hyperparameter Tuning)']
# Out:
# [0.9257425742574258,
#  0.905982905982906,
#  0.9636363636363636,
#  0.933920704845815,
#  np.float64(0.9529411764705882),
#  np.float64(0.8804347826086957)]

# %% [markdown]
# ## Random Forest

# %%
rf_model = RandomForestClassifier(n_estimators=200,criterion='entropy', random_state=42)
start_time = time.perf_counter()
rf_model.fit(x_train, y_train)
model_trainTime['RF'] = time.perf_counter() - start_time
print(f"Training time: {model_trainTime['RF']:.4f} seconds")

y_pred_rf = rf_model.predict(x_val)
# Out:
# Training time: 2.2949 seconds

# %%
metrics_eval(y_val, y_pred_rf)
# Out:
# Accuracy: 0.95
# Precision: 0.9847328244274809
# Recall: 0.9280575539568345
# f1-score: 0.9555555555555556
# NPV: 0.908256880733945
# Specificity: 0.9801980198019802
# (0.95,
#  0.9847328244274809,
#  0.9280575539568345,
#  0.9555555555555556,
#  np.float64(0.908256880733945),
#  np.float64(0.9801980198019802))

# %%
class_rep(y_val, y_pred_rf)
# Out:
#               precision    recall  f1-score  support
# 0              0.908257  0.980198  0.942857   101.00
# 1              0.984733  0.928058  0.955556   139.00
# accuracy       0.950000  0.950000  0.950000     0.95
# macro avg      0.946495  0.954128  0.949206   240.00
# weighted avg   0.952549  0.950000  0.950212   240.00

# %%
rf_cm = metrics.confusion_matrix(y_val, y_pred_rf)
conf_mat(rf_cm)

# %%
# testing
yrf_test_pred = rf_model.predict(x_test)
class_rep(y_test, yrf_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.898990  0.967391  0.931937   92.000000
# 1              0.970874  0.909091  0.938967  110.000000
# accuracy       0.935644  0.935644  0.935644    0.935644
# macro avg      0.934932  0.938241  0.935452  202.000000
# weighted avg   0.938135  0.935644  0.935765  202.000000

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, yrf_test_pred)
# Out:
# Accuracy: 0.9356435643564357
# Precision: 0.970873786407767
# Recall: 0.9090909090909091
# f1-score: 0.9389671361502347
# NPV: 0.898989898989899
# Specificity: 0.967391304347826

# %%
rf_cm_test = metrics.confusion_matrix(y_test, yrf_test_pred)
conf_mat(rf_cm_test)

# %%
model_Performance['Random Forest']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['Random Forest']
# Out:
# [0.9356435643564357,
#  0.970873786407767,
#  0.9090909090909091,
#  0.9389671361502347,
#  np.float64(0.898989898989899),
#  np.float64(0.967391304347826)]

# %% [markdown]
# ## Random Forest (Adjust Parameter)

# %%
pg = {'n_estimators': [20, 50, 75, 100, 150, 175, 180, 190, 200, 300],
    'max_depth': [None, 10, 20, 30, 40, 50, 60]}

rf_model = RandomForestClassifier(random_state=42)
start_time = time.perf_counter()
gs = GridSearchCV(rf_model, pg, cv=5)
gs.fit(x_train, y_train)

print("Best n estimators:", gs.best_params_['n_estimators'])
print("Best max depth:", gs.best_params_['max_depth'])

rf_model = RandomForestClassifier(random_state=42, max_depth = gs.best_params_['max_depth'], n_estimators = gs.best_params_['n_estimators'])
rf_model.fit(x_train, y_train)
model_ht_trainTime['RF'] = time.perf_counter() - start_time
print(f"Training time: {model_ht_trainTime['RF']:.4f} seconds")

y_pred_rf = rf_model.predict(x_val)
# Out:
# Best n estimators: 100
# Best max depth: 30
# Training time: 235.0452 seconds

# %%
metrics_eval(y_val, y_pred_rf)
# Out:
# Accuracy: 0.9166666666666666
# Precision: 0.9473684210526315
# Recall: 0.9064748201438849
# f1-score: 0.9264705882352942
# NPV: 0.8785046728971962
# Specificity: 0.9306930693069307
# (0.9166666666666666,
#  0.9473684210526315,
#  0.9064748201438849,
#  0.9264705882352942,
#  np.float64(0.8785046728971962),
#  np.float64(0.9306930693069307))

# %%
class_rep(y_val, y_pred_rf)
# Out:
#               precision    recall  f1-score     support
# 0              0.878505  0.930693  0.903846  101.000000
# 1              0.947368  0.906475  0.926471  139.000000
# accuracy       0.916667  0.916667  0.916667    0.916667
# macro avg      0.912937  0.918584  0.915158  240.000000
# weighted avg   0.918388  0.916667  0.916949  240.000000

# %%
rf_cm = metrics.confusion_matrix(y_val, y_pred_rf)
conf_mat(rf_cm)

# %%
# testing
yrf_test_pred = rf_model.predict(x_test)
class_rep(y_test, yrf_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.892473  0.902174  0.897297   92.000000
# 1              0.917431  0.909091  0.913242  110.000000
# accuracy       0.905941  0.905941  0.905941    0.905941
# macro avg      0.904952  0.905632  0.905270  202.000000
# weighted avg   0.906064  0.905941  0.905980  202.000000

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, yrf_test_pred)
# Out:
# Accuracy: 0.905940594059406
# Precision: 0.9174311926605505
# Recall: 0.9090909090909091
# f1-score: 0.91324200913242
# NPV: 0.8924731182795699
# Specificity: 0.9021739130434783

# %%
rf_cm_test = metrics.confusion_matrix(y_test, yrf_test_pred)
conf_mat(rf_cm_test)

# %%
model_Performance['Random Forest (Hyperparameter Tuning)']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['Random Forest (Hyperparameter Tuning)']
# Out:
# [0.905940594059406,
#  0.9174311926605505,
#  0.9090909090909091,
#  0.91324200913242,
#  np.float64(0.8924731182795699),
#  np.float64(0.9021739130434783)]

# %% [markdown]
# ## Support Vector Classifier

# %%
svc_model = SVC(random_state=42)
start_time = time.perf_counter()
svc_model.fit(x_train, y_train)
model_trainTime['SVC'] = time.perf_counter() - start_time
y_pred_svc = svc_model.predict(x_val)

print(f"Training time: {model_trainTime['SVC']:.4f} seconds")
# Out:
# Training time: 0.0702 seconds

# %%
metrics_eval(y_val, y_pred_svc)
# Out:
# Accuracy: 0.7791666666666667
# Precision: 0.7443181818181818
# Recall: 0.9424460431654677
# f1-score: 0.8317460317460318
# NPV: 0.875
# Specificity: 0.5544554455445545
# (0.7791666666666667,
#  0.7443181818181818,
#  0.9424460431654677,
#  0.8317460317460318,
#  np.float64(0.875),
#  np.float64(0.5544554455445545))

# %%
class_rep(y_val, y_pred_svc)
# Out:
#               precision    recall  f1-score     support
# 0              0.875000  0.554455  0.678788  101.000000
# 1              0.744318  0.942446  0.831746  139.000000
# accuracy       0.779167  0.779167  0.779167    0.779167
# macro avg      0.809659  0.748451  0.755267  240.000000
# weighted avg   0.799313  0.779167  0.767376  240.000000

# %%
svc_cm = metrics.confusion_matrix(y_val, y_pred_svc)
conf_mat(svc_cm)

# %%
# testing
ysvc_test_pred = svc_model.predict(x_test)
class_rep(y_test, ysvc_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.934426  0.619565  0.745098   92.000000
# 1              0.751773  0.963636  0.844622  110.000000
# accuracy       0.806931  0.806931  0.806931    0.806931
# macro avg      0.843100  0.791601  0.794860  202.000000
# weighted avg   0.834962  0.806931  0.799294  202.000000

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, ysvc_test_pred)
# Out:
# Accuracy: 0.806930693069307
# Precision: 0.75177304964539
# Recall: 0.9636363636363636
# f1-score: 0.8446215139442231
# NPV: 0.9344262295081968
# Specificity: 0.6195652173913043

# %%
svc_cm_test = metrics.confusion_matrix(y_test, ysvc_test_pred)
conf_mat(svc_cm_test)

# %%
model_Performance['SVC']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['SVC']
# Out:
# [0.806930693069307,
#  0.75177304964539,
#  0.9636363636363636,
#  0.8446215139442231,
#  np.float64(0.9344262295081968),
#  np.float64(0.6195652173913043)]

# %% [markdown]
# ## Support Vector Classifier (Adjust Parameter)

# %%
pg= {'C': [0.1, 1, 10],
    'gamma': [0.1, 1, 10]}
svc_model = SVC(random_state=42)
start_time = time.perf_counter()
gs = GridSearchCV(svc_model, pg, cv=5)
gs.fit(x_train, y_train)

print("Best gamma:", gs.best_params_['gamma'])
print("Best C:", gs.best_params_['C'])

svc_model = SVC(random_state=42, gamma=gs.best_params_['gamma'], C=gs.best_params_['C'])
svc_model.fit(x_train, y_train)

model_ht_trainTime['SVC'] = time.perf_counter() - start_time
print(f"Training time: {model_ht_trainTime['SVC']:.4f} seconds")

y_pred_svc = svc_model.predict(x_val)
# Out:
# Best gamma: 0.1
# Best C: 10
# Training time: 2.2752 seconds

# %%
metrics_eval(y_val, y_pred_svc)
# Out:
# Accuracy: 0.9083333333333333
# Precision: 0.920863309352518
# Recall: 0.920863309352518
# f1-score: 0.920863309352518
# NPV: 0.8910891089108911
# Specificity: 0.8910891089108911
# (0.9083333333333333,
#  0.920863309352518,
#  0.920863309352518,
#  0.920863309352518,
#  np.float64(0.8910891089108911),
#  np.float64(0.8910891089108911))

# %%
class_rep(y_val, y_pred_svc)
# Out:
#               precision    recall  f1-score     support
# 0              0.891089  0.891089  0.891089  101.000000
# 1              0.920863  0.920863  0.920863  139.000000
# accuracy       0.908333  0.908333  0.908333    0.908333
# macro avg      0.905976  0.905976  0.905976  240.000000
# weighted avg   0.908333  0.908333  0.908333  240.000000

# %%
svc_cm = metrics.confusion_matrix(y_val, y_pred_svc)
conf_mat(svc_cm)

# %%
# testing
ysvc_test_pred = svc_model.predict(x_test)
class_rep(y_test, ysvc_test_pred)
# Out:
#               precision    recall  f1-score     support
# 0              0.925532  0.945652  0.935484   92.000000
# 1              0.953704  0.936364  0.944954  110.000000
# accuracy       0.940594  0.940594  0.940594    0.940594
# macro avg      0.939618  0.941008  0.940219  202.000000
# weighted avg   0.940873  0.940594  0.940641  202.000000

# %%
acc, prec, rec, f1Score, NPV, specificity = metrics_eval(y_test, ysvc_test_pred)
# Out:
# Accuracy: 0.9405940594059405
# Precision: 0.9537037037037037
# Recall: 0.9363636363636364
# f1-score: 0.944954128440367
# NPV: 0.925531914893617
# Specificity: 0.9456521739130435

# %%
svc_cm_test = metrics.confusion_matrix(y_test, ysvc_test_pred)
conf_mat(svc_cm_test)

# %%
model_Performance['SVC (Hyperparameter Tuning)']= [acc, prec, rec, f1Score, NPV, specificity]
model_Performance['SVC (Hyperparameter Tuning)']
# Out:
# [0.9405940594059405,
#  0.9537037037037037,
#  0.9363636363636364,
#  0.944954128440367,
#  np.float64(0.925531914893617),
#  np.float64(0.9456521739130435)]

# %% [markdown]
# ## All Results

# %%
print(model_trainTime)
# Out:
# {'Naive_Bayes': 0.01590352300001996, 'LR': 0.07160569399999872, 'RF': 2.2948915169999964, 'SVC': 0.07023424600004091}

# %%
time1 = pd.DataFrame(model_trainTime, index=['Time']).transpose().reset_index()
time1.to_csv('time1.csv', index=False)
time1
# Out:
#          index      Time
# 0  Naive_Bayes  0.015904
# 1           LR  0.071606
# 2           RF  2.294892
# 3          SVC  0.070234

# %%
print(model_ht_trainTime)
# Out:
# {'Naive_Bayes': 1.6513470810000115, 'LR': 2.6477682409999943, 'RF': 235.04520225599998, 'SVC': 2.2752009189999853}

# %%
time2 = pd.DataFrame(model_ht_trainTime, index=['Time']).transpose().reset_index()
time2.to_csv('time2.csv', index=False)
time2
# Out:
#          index        Time
# 0  Naive_Bayes    1.651347
# 1           LR    2.647768
# 2           RF  235.045202
# 3          SVC    2.275201

# %%
result = pd.DataFrame(model_Performance, index=['Accuracy', 'Precision', 'Recall', 'F1-Score', 'NPV', 'Specificity'])
result = result.transpose().reset_index()
result
# Out:
#                                          index  Accuracy  Precision    Recall  \
# 0                                  Naive Bayes  0.757426   0.691824  1.000000
# 1          Naive Bayes (Hyperparameter Tuning)  0.841584   0.786765  0.972727
# 2                          Logistic Regression  0.831683   0.771429  0.981818
# 3  Logistic Regression (Hyperparameter Tuning)  0.925743   0.905983  0.963636
# 4                                Random Forest  0.935644   0.970874  0.909091
# 5        Random Forest (Hyperparameter Tuning)  0.905941   0.917431  0.909091
# 6                                          SVC  0.806931   0.751773  0.963636
# 7                  SVC (Hyperparameter Tuning)  0.940594   0.953704  0.936364
#
#    F1-Score       NPV  Specificity
# 0  0.817844  1.000000     0.467391
# 1  0.869919  0.954545     0.684783
# 2  0.864000  0.967742     0.652174
# 3  0.933921  0.952941     0.880435
# 4  0.938967  0.898990     0.967391
# 5  0.913242  0.892473     0.902174
# 6  0.844622  0.934426     0.619565
# 7  0.944954  0.925532     0.945652

# %%
result.to_csv('model_performance.csv', index=False)
